# %% [markdown]
# <a href="https://colab.research.google.com/github/siva12309521/Data-Science-Mini-Projects/blob/main/Self_Project_2_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Do an initial research on the dataset given below and try to do the initial steps
# like we did on our previous project.

# %% [markdown]
# https://www.kaggle.com/datasets/uciml/iris

# %%
# !git clone https://github.com/siva12309521/projects.git
# Out:
# fatal: destination path 'projects' already exists and is not an empty directory.

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
iris = pd.read_csv("/content/drive/MyDrive/data/Iris.csv")

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# **About Dataset**
#
# The Iris dataset was used in R.A. Fisher's classic 1936 paper, The Use of
#
# Multiple Measurements in Taxonomic Problems, and can also be found on the UCI
#
# Machine Learning Repository.
#
# It includes three iris species with 50 samples each as well as some properties
#
# about each flower. One flower species is linearly separable from the other two,
#
# but the other two are not linearly separable from each other.
#
# The columns in this dataset are:
#
# Id
#
# SepalLengthCm
#
# SepalWidthCm
#
# PetalLengthCm
#
# PetalWidthCm
#
# Species

# %% [markdown]
# 2. Do the following things compulsorily, you can add your own data analysis and
# preprocessing.
#
# a. Check for missing data.

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# b. Print the dimension of the dataset

# %%
iris.shape
# Out:
# (150, 6)

# %% [markdown]
# c. Print Statistical summary using the description.

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# d.. Print the range of the SepalLengthCm

# %%
range = iris['SepalLengthCm'].max() - iris['SepalLengthCm'].min()
print(f"The range of SepalLengthCm is: {range}")
# Out:
# The range of SepalLengthCm is: 3.6000000000000005

# %% [markdown]
# e. Print the range of the SepalWidthCm

# %%
range = iris["SepalWidthCm"].max()- iris["SepalWidthCm"].min()
print(f"The range of SepalWidthCm is: {range}")
# Out:
# The range of SepalWidthCm is: 2.4000000000000004

# %% [markdown]
# f. Print the range of the PetalLengthCm

# %%
range = iris["PetalLengthCm"].max()- iris["PetalLengthCm"].min()
print(f"The range of PetalLengthCm is : {range}")
# Out:
# The range of PetalLengthCm is : 5.9

# %% [markdown]
# g. Print the range of the PetalWidthCm

# %%
range = iris["PetalWidthCm"].max()-iris["PetalWidthCm"].min()
print(f"The range of PetalWidthCm is: {range}")
# Out:
# The range of PetalWidthCm is: 2.4

# %% [markdown]
# 3. Is this a classification or regression problem? Explain?

# %% [markdown]
# The Iris dataset is a classification problem because
#
# the goal is to predict the species of an iris flower,
#
# which is a categorical variable (Setosa, Versicolor,
#
# or Virginica). Classification problems predict
#
# discrete labels, while regression problems predict
#
# continuous values.

# %% [markdown]
# 4. Do all proper data preprocessing.

# %%
iris['SepalLengthCm'].fillna(iris['SepalLengthCm'].mean(), inplace=True)
# Out:
# /tmp/ipython-input-3188925389.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   iris['SepalLengthCm'].fillna(iris['SepalLengthCm'].mean(), inplace=True)

# %% [markdown]
# 5.Do all the data visualization you think necessary.

# %%
# Scatter plot of Sepal Length vs Sepal Width, colored by Species
plt.figure(figsize=(7,6))
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species',data=iris)
plt.title('Sepal Length vs Sepal Width')
# Out:
# Text(0.5, 1.0, 'Sepal Length vs Sepal Width')

# %%
# Histogram of Sepal Length, colored by Species
plt.figure(figsize=(7,6))
sns.histplot(x='SepalLengthCm', hue='Species',data=iris)
plt.title('Distribution of Sepal Length')
# Out:
# Text(0.5, 1.0, 'Distribution of Sepal Length')

# %%
# Box plot of Petal Length by Species
plt.figure(figsize=(7,6))
sns.boxplot(x='Species', y='PetalLengthCm',data=iris)
plt.title('Petal Length by Species')
# Out:
# Text(0.5, 1.0, 'Petal Length by Species')

# %%
# Pair plot of all features, colored by Species
sns.pairplot(iris, hue='Species')
plt.title('Pair Plot of Iris Features')
plt.show()

# %% [markdown]
# 6.Write down all the conclusions you derived from the data.

# %%
#1.Species Distinction 2.Sepal and Petal Dimensions 3.Petal Length and Width:4.Setosa Identification5.Versicolor and Virginica Overlap:

# %% [markdown]
# **1.Species Distinction:** The three Iris species
#
# (Setosa, Versicolor, and Virginica) have distinct
#
# characteristics based on their sepal and petal
#
# measurements. This is evident from the scatter plots
#
# and box plots which show clear separation between the
#
# species, especially when considering petal length and
#
# width.
#
# **2.Sepal and Petal Dimensions:** Sepal length and
#
# width exhibit some overlap between species, making
#
# them less effective for species classification
#
# compared to petal measurements.
#
# **3.Petal Length and Width:** Petal length and width
#
# are highly correlated and appear to be the most
#
# important features for distinguishing between Iris
#
# species.
#
# **4.Setosa Identification:** Iris Setosa is easily
#
# separable from the other two species based on its
#
# smaller petal length and width.
#
# **5.Versicolor and Virginica Overlap:** While
#
# distinguishable, Iris Versicolor and Iris Virginica
#
# show some overlap in their sepal and petal
#
# measurements, making their classification slightly
#
# more challenging.
#
# **6.Data Distribution:** The histograms reveal that
#
# sepal length follows a roughly normal distribution,
#
# while other features may have slightly skewed
#
# distributions.
#
# **7.Outliers:** The box plots indicate the presence of
#
# potential outliers, especially in sepal width for Iris
#
# Setosa. Further investigation might be needed to
#
# determine if these outliers are valid data points or
#
# errors.
#
# **8.Correlation:** The pair plot showcases the
#
# relationships between different features, highlighting
#
# the strong positive correlation between petal length
#
# and width.

# %% [markdown]
# 7.Split the data into train test split (60% for training and 40% for testing)

# %%
iris.drop("Id",axis=1,inplace=True)
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
x=iris.drop("Species",axis="columns")
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y=iris.drop(["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"],axis="columns")
y
# Out:
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train , y_test = train_test_split(x,y, test_size=0.2, random_state=2)

# %% [markdown]
# 8.Built a model and train the data.

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_ir=model.predict(x_test)
y_ir
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica'], dtype=object)

# %%
model.predict_proba(x_test)
# Out:
# array([[9.80361711e-01, 1.96382095e-02, 7.90324807e-08],
#        [9.64864366e-01, 3.51354838e-02, 1.50485990e-07],
#        [3.16391401e-04, 1.61649391e-01, 8.38034218e-01],
#        [9.63123148e-01, 3.68767668e-02, 8.50790834e-08],
#        [9.33974922e-01, 6.60243998e-02, 6.77788096e-07],
#        [3.01458699e-05, 1.48699093e-01, 8.51270761e-01],
#        [9.34360179e-01, 6.56395107e-02, 3.09849308e-07],
#        [9.76954457e-06, 6.30355734e-02, 9.36954657e-01],
#        [1.90058405e-05, 4.35308377e-02, 9.56450156e-01],
#        [9.62586372e-01, 3.74134754e-02, 1.52786916e-07],
#        [9.71814554e-01, 2.81853729e-02, 7.26082360e-08],
#        [9.82699426e-01, 1.73005271e-02, 4.68529448e-08],
#        [9.78174023e-01, 2.18259436e-02, 3.39086494e-08],
#        [9.62936755e-01, 3.70629867e-02, 2.58008862e-07],
#        [1.17183289e-02, 7.61860908e-01, 2.26420763e-01],
#        [3.08979680e-03, 7.85141823e-01, 2.11768380e-01],
# ...

# %% [markdown]
# 9.Explain the performance of the model.

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_ir)
print(f"Accuracy:{accuracy:2f}")
# Out:
# Accuracy:0.966667

# %%
y_ir=model.predict([[5.1,3.5,1.4,0.2]])
print(y_ir)
# Out:
# ['Iris-setosa']
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

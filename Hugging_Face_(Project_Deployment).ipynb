# %% [markdown]
# <a href="https://colab.research.google.com/github/siva12309521/Data-Science-Mini-Projects/blob/main/Hugging_Face_(Project_Deployment).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Please deploy any two generative AI projects on Hugging Face, and provide the
# project links along with screenshots.

# %% [markdown]
# ![Screenshot 2025-08-25 142348.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-08-25 142654.png](data:image/png;base64,...)

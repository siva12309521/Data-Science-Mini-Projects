# %% [markdown]
# <a href="https://colab.research.google.com/github/siva12309521/Data-Science-Mini-Projects/blob/main/homeprice(Algorithms).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
home = pd.read_csv("/content/drive/MyDrive/data/homeprices (7).csv")

# %%
home
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
home.shape
# Out:
# (5, 2)

# %%
home.isnull().sum()
# Out:
# area     0
# price    0
# dtype: int64

# %%
home.describe()
# Out:
#               area          price
# count     5.000000       5.000000
# mean   3280.000000  626000.000000
# std     540.370243   74949.983322
# min    2600.000000  550000.000000
# 25%    3000.000000  565000.000000
# 50%    3200.000000  610000.000000
# 75%    3600.000000  680000.000000
# max    4000.000000  725000.000000

# %%
home.tail()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
home.head(2)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000

# %%
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(home.area,home.price,color = "red",marker="*")

# %%
x=home.drop("price",axis="columns")

# %%
x
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
y=home.price

# %%
y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
# create linear regression object
reg = linear_model.LinearRegression()

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.predict([[50]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([187405.82191781])

# %%
reg.predict([[2600]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([533664.38356164])

# %%
homeprice = pd.read_csv("/content/drive/MyDrive/data/homeprices (6).csv")

# %%
homeprice
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
homeprice.isnull().sum()
# Out:
# area        0
# bedrooms    1
# age         0
# price       0
# dtype: int64

# %%
plt.xlabel(["area","age","bedrooms"])
plt.ylabel("price")
plt.scatter(home.area,home.price,color = "red",marker="*")

# %%
homeprice1 = homeprice.fillna(homeprice["bedrooms"].median())

# %%
homeprice1
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
homeprice1.isnull().sum()
# Out:
# area        0
# bedrooms    0
# age         0
# price       0
# dtype: int64

# %%
ho=linear_model.LinearRegression()
ho.fit(homeprice1.drop("price",axis="columns"),homeprice1.price)
# Out:
# LinearRegression()

# %%
ho.predict([[600,3,40]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([229458.39091918])

# %%
new= pd.read_csv("/content/drive/MyDrive/data/multilinear_regression_dataset.csv")

# %%
new
# Out:
#    Years_of_Experience  Education_Level  Age  Salary
# 0                    1               12   22   40000
# 1                    3               14   25   48000
# 2                    5               16   27   58000
# 3                    7               16   30   67000
# 4                    9               18   32   78000
# 5                   11               18   35   90000
# 6                   13               20   38  102000
# 7                   15               20   40  115000
# 8                   17               22   43  130000
# 9                   20               22   47  150000

# %%
new.isnull().sum()
# Out:
# Years_of_Experience    0
# Education_Level        0
# Age                    0
# Salary                 0
# dtype: int64

# %%
plt.xlabel(["Years_of_Experience","Education_Level","Age"])
plt.ylabel("Salary")
plt.scatter(new.Years_of_Experience,new.Salary,color = "red",marker="*")

# %%
ne=linear_model.LinearRegression()
ne.fit(new.drop("Salary",axis="columns"),new.Salary)
# Out:
# LinearRegression()

# %%
ne.predict([[9,18,40]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([96823.86595832])
